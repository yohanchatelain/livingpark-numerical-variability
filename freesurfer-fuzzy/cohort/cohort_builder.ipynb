# %%
import livingpark_utils
import pandas as pd
import numpy as np

from collections import defaultdict
from itertools import combinations
from typing import Dict
from pathlib import Path

from collections.abc import Iterable

import rich
from rich.console import Console
from rich.table import Table

anonymizer = True

root_dir = Path.cwd()


def anondir(path: Path, prefix=root_dir) -> Path:
    """Anonymize a directory path by replacing user-specific parts with <root>."""
    if not anonymizer:
        return path
    path_str = str(path).replace(str(prefix), "<living-park>")
    return Path(path_str)


cohort_dir = root_dir / "cohort"
if not anonymizer:
    print(f"Current working directory: {root_dir}")
else:
    print(f"Current working directory: {anondir(root_dir)}")
print(f"Cohort directory: {anondir(cohort_dir)}")

utils = livingpark_utils.LivingParkUtils()
random_seed = 2
utils.notebook_init()

import warnings

warnings.filterwarnings("ignore")
# Out:
# Current working directory: <living-park>
# Cohort directory: <living-park>/cohort
# This notebook was run on 2025-11-12 21:37:18 UTC +0000

# %%
import livingpark_utils
from livingpark_utils.download import ppmi

utils = livingpark_utils.LivingParkUtils()
print("Study files directory:", anondir(utils.study_files_dir))
downloader = ppmi.Downloader(utils.study_files_dir)

required_files = [
    "Demographics.csv",
    "Age_at_visit.csv",
    "Primary_Clinical_Diagnosis.csv",
    "Cognitive_Categorization.csv",
    "Medical_Conditions_Log.csv",
    "Concomitant_Medication_Log.csv",
    "MDS-UPDRS_Part_III.csv",
    "Participant_Status.csv",
    "Socio-Economics.csv",
    "Montreal_Cognitive_Assessment__MoCA_.csv",
    "PD_Diagnosis_History.csv",
    "LEDD_Concomitant_Medication_Log.csv",
]

utils.notebook_init()
utils.get_study_files(required_files, default=downloader)
# Out:
# Study files directory: <living-park>/inputs/study_files
# This notebook was run on 2025-11-12 21:37:18 UTC +0000
# Download skipped: No missing files!

# %%
from livingpark_utils.scripts import run

run.mri_metadata()

# %% [markdown]
# # Cohort preparation
#
# We will build a cohort using data from Parkinson's Progression Markers Initiative (PPMI). We will select patients with Parkinson's disease (PD) with (PD-MCI) and without Mild Cognitive Impairment (PD-non-MCI) as well as healthy controls (HC). The cohort will be built directly from PPMI Study Data so that it can be replicated and updated whenever necessary.
#
# We will use the LivingPark utils library to download files from the notebook. If files are already present in the notebook cache, they won't be downloaded again. Otherwise, you will need to enter your PPMI username and password. **In case you don't have a PPMI account, you can request one [here](http://ppmi-info.org).**

# %%
import os
import pandas as pd


# Read data files
def pd_from_csv(file_name):
    return pd.read_csv(os.path.join(utils.study_files_dir, file_name))


# Demographics
fields = ["PATNO", "SEX", "BIRTHDT"]
dem = pd_from_csv("Demographics.csv")[fields]

# Age at visit
fields = ["PATNO", "EVENT_ID", "AGE_AT_VISIT"]
age = pd_from_csv("Age_at_visit.csv")[fields]

# Education
fields = ["PATNO", "EDUCYRS"]
edu = pd_from_csv("Socio-Economics.csv")[fields]

# Diagnosis
fields = ["PATNO", "EVENT_ID", "PRIMDIAG", "OTHNEURO"]
diag = pd_from_csv("Primary_Clinical_Diagnosis.csv")[fields]

# Dx status
fields = ["PATNO", "COHORT"]
dx_status = pd_from_csv("Participant_Status.csv")[fields]

# PD dx history / disease duration calc
fields = ["PATNO", "EVENT_ID", "PDDXDT"]
pd_hist = pd_from_csv("PD_Diagnosis_History.csv")[fields]

# Cognitive Categorization
fields = ["PATNO", "EVENT_ID", "COGSTATE"]
cog_cat = pd_from_csv("Cognitive_Categorization.csv")[fields]

# UPDRS and Hoehh Yahr
fields = ["PATNO", "EVENT_ID", "PDSTATE", "NP3TOT", "NHY"]
updrs = pd_from_csv("MDS-UPDRS_Part_III.csv")[fields]

# Clean UPDRS file. Impute missing ON/OFF values.
# It produces MDS_UPDRS_Part_III_clean.csv file
# from livingpark_utils.scripts import pd_status
fields = ["PATNO", "EVENT_ID", "PDSTATE", "NP3TOT", "NHY", "PDTRTMNT"]
updrs = pd_from_csv("MDS_UPDRS_Part_III_clean.csv")[fields]

# %% [markdown]
# We will also need file `MRI_info.csv` produced by another LivingPark notebook available at https://github.com/LivingPark-MRI/livingpark-utils/blob/main/livingpark_utils/notebooks/mri_metadata.ipynb. This file contains a list of T1-weighted MRI images.

# %%
import numpy as np

# Calculate disease duration

from dateutil.parser import parse
from dateutil.relativedelta import relativedelta

pdxhist = pd_hist[(pd_hist["EVENT_ID"] == "SC") & pd_hist["PDDXDT"].notna()]

fields = ["PATNO", "EVENT_ID", "INFODT"]
pd_dur = pd_from_csv("MDS_UPDRS_Part_III_clean.csv")[fields]

PDDXDT_map = dict(zip(pdxhist["PATNO"].values, pdxhist["PDDXDT"].values))
pd_dur["PDDXDT"] = pd_dur["PATNO"].map(PDDXDT_map)


def parse_date(row):
    if row["PDDXDT"] is not np.nan:
        return relativedelta(parse(row["INFODT"]), parse(row["PDDXDT"])).months
    else:
        return np.nan


pd_dur["PDXDUR"] = pd_dur.apply(parse_date, axis=1)
pd_dur.drop(labels=["INFODT", "PDDXDT"], inplace=True, axis=1)

# %%
# MRI availability

mri = pd_from_csv("MRI_info.csv")
mri["EVENT_ID"] = mri["Visit code"]
mri["PATNO"] = mri["Subject ID"]
mri["Sex"] = mri["Sex"].map({"F": 0, "M": 1})
mri = mri.drop(["Subject ID", "Visit code", "Visit", "Age", "Sex"], axis=1)
mri.groupby("EVENT_ID").size().sort_values(ascending=False).head(5)
# Out:
# EVENT_ID
# BL     2937
# V04     653
# V10     468
# V06     437
# ST       10
# dtype: int64

# %% [markdown]
# ## Pair visits

# %%
# Find visit pairs

from collections import defaultdict
from itertools import combinations
from typing import Dict

visit2month = {
    "BL": 0,
    "V01": 3,
    "V02": 6,
    "V03": 9,
    "V04": 12,
    "V05": 18,
    "V06": 24,
    "V07": 30,
    "V08": 36,
    "V09": 42,
    "V10": 48,
    "V11": 54,
    "V12": 60,
    "V13": 72,
    "V14": 84,
    "V15": 96,
    "V16": 108,
    "V17": 120,
    "V18": 132,
    "V19": 144,
    "V20": 156,
}


def find_visit_pairs(months: int) -> Dict[str, str]:
    """Return the pairs of visits closest to each other, given a target time difference in months."""

    closest_diff = float("inf")
    closest_pairs = defaultdict(dict)

    for (visit1, month1), (visit2, month2) in combinations(visit2month.items(), 2):
        current_diff = abs(abs(month1 - month2) - months)
        if current_diff <= closest_diff:
            closest_diff = current_diff
            closest_pairs[closest_diff][visit1] = visit2

    return closest_pairs[closest_diff]

# %% [markdown]
# # Select HC

# %%
# diagnosis - use screening instead of baseline when PRIMDIAG is missing at baseline

# Diagnosis
# fields = ["PATNO", "EVENT_ID", "PRIMDIAG", "OTHNEURO"]
# diag = pd_from_csv("Primary_Clinical_Diagnosis.csv")[fields]

diag_bl = diag[diag["EVENT_ID"] == "BL"]
diag_other = diag[diag["EVENT_ID"] != "BL"]
diag_other["EVENT_ID"].mask(diag_other["EVENT_ID"] == "SC", "BL", inplace=True)

diag_hc = pd.concat([diag_bl, diag_other])
diag_hc = diag_hc.drop_duplicates()

# %%
# merge into a single df
df_hc = (
    mri.merge(diag_hc, on=["PATNO", "EVENT_ID"])
    .merge(age, on=["PATNO", "EVENT_ID"], how="left")
    .merge(dem, on=["PATNO"], how="left")
    .merge(dx_status, on=["PATNO"], how="left")  # check
    .merge(edu, on=["PATNO"], how="left")
    .merge(cog_cat, on=["PATNO", "EVENT_ID"], how="left")
    .merge(pd_hist, on=["PATNO", "EVENT_ID"], how="left")
    .drop_duplicates()
    .groupby("PATNO")
    .filter(lambda g: g["EVENT_ID"].nunique() > 1)
)

# %%
# find how many visit pairs are available for specific group
def find_unique_visit_pairs(df, events, group, get_set_event):
    print(f"Unique {group} subjects per visit pairs:")
    for c in combinations(events, 2):
        v0 = get_set_event(df, c[0])
        v1 = get_set_event(df, c[1])
        if len(v0 & v1):
            print(
                f"{c[0]:3} & {c[1]:3} = {len(v0 & v1):>3}"
                f" | Month difference: {visit2month[c[1]] - visit2month[c[0]]}"
            )
    #       print(v0 & v1)

# %%
# find how many visit pairs are available for HC group
def get_set_event(df, event):
    return set(df[(df["EVENT_ID"] == event) & (df["PRIMDIAG"] == 17)]["PATNO"].values)


events = ["BL", "V04", "V06", "V08", "V10"]
find_unique_visit_pairs(df_hc, events, "HC", get_set_event)
# Out:
# Unique HC subjects per visit pairs:
# BL  & V04 = 104 | Month difference: 12
# BL  & V06 =  45 | Month difference: 24
# BL  & V08 =   2 | Month difference: 36
# BL  & V10 = 116 | Month difference: 48
# V04 & V06 =  16 | Month difference: 12
# V04 & V08 =   1 | Month difference: 24
# V04 & V10 =  13 | Month difference: 36
# V06 & V08 =   2 | Month difference: 12
# V06 & V10 =  19 | Month difference: 24

# %%
def pairs_hc(arg):
    """
    Return HC subjects that have a visit pair with the specified time difference in months
    """
    visit_pairs = find_visit_pairs(arg)
    visit_df = df_hc.copy()
    visit_df["NEXT_VISIT"] = visit_df["EVENT_ID"].map(visit_pairs)

    visit_df = visit_df.merge(
        visit_df.drop(
            ["AGE_AT_VISIT", "SEX", "NEXT_VISIT", "EDUCYRS"],
            axis=1,
        ),
        left_on=[
            "PATNO",
            "NEXT_VISIT",
        ],
        right_on=[
            "PATNO",
            "EVENT_ID",
        ],
        suffixes=(None, "_NX"),
    ).drop_duplicates()

    return visit_df.loc[(visit_df["PRIMDIAG"] == 17) & (visit_df["PRIMDIAG_NX"] == 17)]

# %%
# build database of all available HC
hc_12 = pairs_hc(12)
hc_24 = pairs_hc(24)
hc_36 = pairs_hc(36)
hc = pd.concat([hc_12, hc_24, hc_36], ignore_index=True)
hc = hc.loc[hc["COHORT"].isin([2, 4])]
hc = hc.drop_duplicates(subset=["PATNO"])
hc["dx_group"] = "HC"
print("Unique HC number before selection: ", hc["PATNO"].unique().size)
# Out:
# Unique HC number before selection:  138

# %% [markdown]
# # Data aggregation for PD

# %%
# Merge into a single df for PD
df = (
    mri.merge(diag, on=["PATNO", "EVENT_ID"])
    .merge(age, on=["PATNO", "EVENT_ID"], how="left")
    .merge(dem, on=["PATNO"])
    .merge(edu, on=["PATNO"], how="left")
    .merge(dx_status, on=["PATNO"])
    .merge(pd_hist, on=["PATNO", "EVENT_ID"], how="left")
    .merge(cog_cat, on=["PATNO", "EVENT_ID"])
    .drop_duplicates()
    .groupby("PATNO")
    .filter(lambda g: g["EVENT_ID"].nunique() > 1)
)

# %%
# Pair PD-non-MCI
def get_set_event(df, event):
    return set(
        df[
            (df["EVENT_ID"] == event)
            & (df["PRIMDIAG"] == 1)
            & (df["COGSTATE"] == 1)
            & (df["COHORT"] == 1)
            & (df["OTHNEURO"].isnull())
        ]["PATNO"].values
    )


events = ["BL", "V04", "V06", "V08", "V10"]
find_unique_visit_pairs(df, events, "PD-non-MCI", get_set_event)
# Out:
# Unique PD-non-MCI subjects per visit pairs:
# BL  & V04 = 151 | Month difference: 12
# BL  & V06 =  60 | Month difference: 24
# V04 & V06 = 123 | Month difference: 12
# V04 & V10 =  58 | Month difference: 36
# V06 & V10 =  81 | Month difference: 24

# %%
# Pair PD-MCI
def get_set_event(df, event):
    return set(
        df[
            (df["EVENT_ID"] == event)
            & (df["PRIMDIAG"] == 1)
            & (df["COGSTATE"] == 2)
            & (df["COHORT"] == 1)
            & (df["OTHNEURO"].isnull())
        ]["PATNO"].values
    )


events = ["BL", "V04", "V06", "V08", "V10"]
find_unique_visit_pairs(df, events, "PD-MCI", get_set_event)
# Out:
# Unique PD-MCI subjects per visit pairs:
# BL  & V04 =  12 | Month difference: 12
# BL  & V06 =   3 | Month difference: 24
# V04 & V06 =  11 | Month difference: 12
# V04 & V10 =   6 | Month difference: 36
# V06 & V10 =  16 | Month difference: 24

# %% [markdown]
# # Select PD-MCI patients

# %%
def get_mci_patients(df):
    return df.loc[
        (df["COGSTATE"] == 2)
        & (df["PRIMDIAG"] == 1)
        & (df["COHORT"] == 1)
        & (df["OTHNEURO"].isnull())
        & (df["COGSTATE_NX"] == 2)
        & (df["PRIMDIAG_NX"] == 1)
        & (df["COHORT_NX"] == 1)
        & (df["OTHNEURO_NX"].isnull())
    ]


def pairs_mci(arg):
    visit_pairs = find_visit_pairs(arg)
    visit_df = df.copy()
    visit_df["NEXT_VISIT"] = visit_df["EVENT_ID"].map(visit_pairs)

    visit_df = visit_df.merge(
        visit_df.drop(
            ["AGE_AT_VISIT", "SEX", "NEXT_VISIT", "EDUCYRS"],
            axis=1,
        ),
        left_on=[
            "PATNO",
            "NEXT_VISIT",
        ],
        right_on=[
            "PATNO",
            "EVENT_ID",
        ],
        suffixes=(None, "_NX"),
    ).drop_duplicates()

    return get_mci_patients(visit_df)

# %%
mci = pairs_mci(12)
mci = mci.drop_duplicates(subset=["PATNO"])

mci_24 = pairs_mci(24)
mci = pd.concat([mci, mci_24], ignore_index=True)
mci = mci.drop_duplicates(subset=["PATNO"])

mci_36 = pairs_mci(36)
mci = pd.concat([mci, mci_36], ignore_index=True)
mci = mci.drop_duplicates(subset=["PATNO"])

mci["dx_group"] = "PD-MCI"
print("There are ", len(mci), " PD-MCI patients.")
# Out:
# There are  36  PD-MCI patients.

# %% [markdown]
# # Select PD-non-MCI patients

# %%
def get_nonmci_patients(df):
    return df.loc[
        (df["COGSTATE"] == 1)
        & (df["PRIMDIAG"] == 1)
        & (df["COHORT"] == 1)
        & (df["OTHNEURO"].isnull())
        & (df["COGSTATE_NX"] == 1)
        & (df["PRIMDIAG_NX"] == 1)
        & (df["COHORT_NX"] == 1)
        & (df["OTHNEURO_NX"].isnull())
    ]


def pairs_nonmci(arg):
    visit_pairs = find_visit_pairs(arg)
    visit_df = df.copy()
    visit_df["NEXT_VISIT"] = visit_df["EVENT_ID"].map(visit_pairs)

    visit_df = visit_df.merge(
        visit_df.drop(
            ["AGE_AT_VISIT", "SEX", "NEXT_VISIT", "EDUCYRS"],
            axis=1,
        ),
        left_on=[
            "PATNO",
            "NEXT_VISIT",
        ],
        right_on=[
            "PATNO",
            "EVENT_ID",
        ],
        suffixes=(None, "_NX"),
    ).drop_duplicates()

    return get_nonmci_patients(visit_df)

# %%
wo_mci_12 = pairs_nonmci(12)
wo_mci_24 = pairs_nonmci(24)
wo_mci_36 = pairs_nonmci(36)
wo_mci_all = pd.concat([wo_mci_12, wo_mci_24, wo_mci_36], ignore_index=True)
wo_mci_all = wo_mci_all.drop_duplicates(subset=["PATNO"])
wo_mci_all["dx_group"] = "PD-non-MCI"

print("There are ", len(wo_mci_all), " PD-non-MCI patients.")
# Out:
# There are  273  PD-non-MCI patients.

# %% [markdown]
# ## cohort to download

# %%
pd.read_csv("freesurfer-variability-Sokol/cohort_stat.csv")
# Out:
#      Study Date                     Description  \
# 0    2021-06-10          3D-T1-weighted_SAGITAL
# 1    2021-04-27                  3D T1-weighted
# 2    2021-06-20          3D-T1-weighted_SAGITAL
# 3    2022-02-07  Sagittal 3D Accelerated MPRAGE
# 4    2022-04-04                  3D_T1-weighted
# 5    2022-04-18  Sagittal 3D Accelerated MPRAGE
# 6    2022-03-15                  3D T1-weighted
# 7    2014-02-19                   MPRAGE GRAPPA
# 8    2013-02-13                   MPRAGE GRAPPA
# 9    2013-04-03                   MPRAGE GRAPPA
# 10   2013-03-13                   MPRAGE GRAPPA
# 11   2013-06-05                   MPRAGE GRAPPA
# 12   2014-01-14                   MPRAGE GRAPPA
# 13   2013-05-15                   MPRAGE GRAPPA
# 14   2014-08-07                   MPRAGE GRAPPA
# 15   2013-03-13                   MPRAGE GRAPPA
# 16   2013-09-12                   MPRAGE GRAPPA
# 17   2014-06-05                   MPRAGE GRAPPA
# 18   2013-01-07                   MPRAGE GRAPPA
# 19   2012-12-06                   MPRAGE GRAPPA
# 20   2013-11-13                   MPRAGE GRAPPA
# 21   2014-08-12                   MPRAGE GRAPPA
# 22   2015-02-19                   MPRAGE GRAPPA
# 23   2020-11-04                   SAG 3D MPRAGE
# 24   2013-07-29                   MPRAGE GRAPPA
# 25   2014-05-19                   MPRAGE GRAPPA
# 26   2013-06-12                   MPRAGE GRAPPA
# 27   2021-01-27                 3D T1 _weighted
# 28   2020-12-16                 3D T1 _weighted
# 29   2020-12-09                 3D T1 _weighted
# 30   2021-03-02                  3D T1-weighted
# 31   2020-12-22                   SAG 3D MPRAGE
# 32   2021-03-29                  3D_T1-weighted
# 33   2021-03-23                  3D T1-weighted
# 34   2021-03-16                  3D T1-weighted
# 35   2021-04-07                    MPRAGE - Sag
# 36   2021-03-31                 SAG 3D T1 FSPGR
# 37   2021-03-26                   SAG 3D MPRAGE
# 38   2021-04-20                 SAG 3D T1 FSPGR
# 39   2021-04-12                  3D_T1-weighted
# 40   2021-06-11          3D-T1-weighted_SAGITAL
# 41   2021-04-14                 SAG 3D T1 FSPGR
# 42   2021-03-30                   SAG 3D MPRAGE
# 43   2021-04-19                  3D T1-weighted
# 44   2021-05-04                  3D T1-weighted
# 45   2021-04-27                  3D T1-weighted
# 46   2021-06-15             MPRAGE SAG IPAT ISO
# 47   2021-05-19                 SAG 3D T1 FSPGR
# 48   2021-06-28      T1-weighted, 3D VOLUMETRIC
# 49   2021-06-10                  3D T1-weighted
# 50   2021-08-23                    3D T1 MPRAGE
# 51   2021-05-25                  3D T1-weighted
# 52   2021-06-10                  3D T1-weighted
# 53   2021-07-28                 3D T1 _weighted
# 54   2021-09-15                  3D T1-weighted
# 55   2021-07-07                   SAG 3D MPRAGE
# 56   2021-09-17                  3D T1-WEIGHTED
# 57   2021-06-22                 SAG 3D T1 FSPGR
# 58   2021-09-02                  3D T1-WEIGHTED
# 59   2021-07-27               3D T1-weighted_ND
# 60   2021-07-15                  3D T1-weighted
# 61   2021-08-05                  3D T1-weighted
# 62   2021-07-29                  3D T1-weighted
# 63   2021-08-31                  3D T1-weighted
# 64   2021-09-16                  3D T1-weighted
# 65   2021-10-14                  3D T1-weighted
# 66   2021-09-14               3D T1-weighted_ND
# 67   2021-10-04                  3D_T1-weighted
# 68   2021-12-02          3D-T1-weighted_SAGITAL
# 69   2021-10-18               3D T1-weighted_ND
# 70   2021-11-02                  3D_T1-weighted
# 71   2021-11-16                  3D T1-weighted
# 72   2021-11-03                    3D T1 MPRAGE
# 73   2021-11-10                    3D T1 MPRAGE
# 74   2021-12-02              SAG 3D T1-weighted
# 75   2021-11-18                  3D T1-weighted
# 76   2021-12-07                  3D T1-weighted
# 77   2022-01-13                    3D T1 MPRAGE
# 78   2021-12-13                   SAG 3D MPRAGE
# 79   2022-01-11                  3D T1-weighted
# 80   2022-01-18                  3D T1-weighted
# 81   2022-02-08                SAG 3D T1 MPRAGE
# 82   2022-02-02                  3D_T1-weighted
# 83   2022-01-20                  3D_T1-weighted
# 84   2022-02-04                       SAG 3D T1
# 85   2022-01-18                    3DT1weighted
# 86   2022-02-16                 3D T1 _weighted
# 87   2022-03-01                  3D T1-weighted
# 88   2022-03-08                  3D T1-weighted
# 89   2022-04-11                    3D T1 MPRAGE
# 90   2022-04-01                  3D T1-weighted
# 91   2022-03-17                  3D T1-weighted
# 92   2022-03-29                  3D T1-weighted
# 93   2022-04-06                 SAG 3D T1 FSPGR
# 94   2022-05-20                  3D T1-weighted
# 95   2022-04-11                    3D T1 MPRAGE
# 96   2022-04-11                  3D T1-weighted
# 97   2022-05-31                  3D T1-weighted
# 98   2013-07-10                   MPRAGE GRAPPA
# 99   2014-03-26                   MPRAGE GRAPPA
# 100  2012-10-09                   MPRAGE GRAPPA
# 101  2013-02-20                   MPRAGE GRAPPA
# 102  2013-04-09               SAG MPRAGE GRAPPA
# 103  2013-05-10               SAG MPRAGE GRAPPA
# 104  2013-08-09               SAG MPRAGE GRAPPA
# 105  2013-11-19               SAG MPRAGE GRAPPA
# 106  2014-03-07               SAG MPRAGE GRAPPA
# 107  2013-01-17               SAG MPRAGE GRAPPA
# 108  2013-02-20               SAG MPRAGE GRAPPA
# 109  2013-10-07                   MPRAGE GRAPPA
# 110  2013-12-20                   MPRAGE GRAPPA
# 111  2014-01-14                   MPRAGE GRAPPA
# 112  2013-02-27                   MPRAGE GRAPPA
# 113  2013-08-01                   MPRAGE GRAPPA
# 114  2013-07-05                   MPRAGE GRAPPA
# 115  2013-08-14                   MPRAGE GRAPPA
# 116  2013-08-21                   MPRAGE GRAPPA
# 117  2014-02-27                   MPRAGE GRAPPA
# 118  2012-10-31                   MPRAGE GRAPPA
# 119  2013-07-12                   MPRAGE GRAPPA
# 120  2013-09-20                   MPRAGE GRAPPA
# 121  2014-05-14                   MPRAGE GRAPPA
# 122  2014-04-23                   MPRAGE GRAPPA
# 123  2013-01-09                   MPRAGE GRAPPA
# 124  2013-02-27                   MPRAGE GRAPPA
# 125  2013-05-29                   MPRAGE GRAPPA
# 126  2013-06-26                   MPRAGE GRAPPA
# 127  2013-07-17                   MPRAGE GRAPPA
# 128  2013-12-11                   MPRAGE GRAPPA
# 129  2012-11-27                   MPRAGE GRAPPA
# 130  2013-04-09                   MPRAGE GRAPPA
# 131  2013-05-28                   MPRAGE GRAPPA
# 132  2013-06-04                   MPRAGE GRAPPA
# 133  2013-09-03                   MPRAGE GRAPPA
# 134  2013-07-30                   MPRAGE GRAPPA
# 135  2013-09-17                   MPRAGE GRAPPA
# 136  2013-10-01                   MPRAGE GRAPPA
# 137  2013-11-26                   MPRAGE GRAPPA
# 138  2013-10-29                   MPRAGE GRAPPA
# 139  2013-12-03                   MPRAGE GRAPPA
# 140  2014-01-28                   MPRAGE GRAPPA
# 141  2014-04-01                   MPRAGE GRAPPA
# 142  2013-09-04                   MPRAGE GRAPPA
# 143  2014-02-10                   MPRAGE GRAPPA
# 144  2012-12-06                   MPRAGE GRAPPA
# 145  2012-10-25                   MPRAGE GRAPPA
# 146  2012-12-11                   MPRAGE GRAPPA
# 147  2013-02-28                   MPRAGE GRAPPA
# 148  2013-02-18                   MPRAGE GRAPPA
# 149  2013-02-20                   MPRAGE GRAPPA
# 150  2013-03-12                   MPRAGE GRAPPA
# 151  2013-08-26                   MPRAGE GRAPPA
# 152  2013-09-18                   MPRAGE GRAPPA
# 153  2013-09-19                   MPRAGE GRAPPA
# 154  2013-10-17                   MPRAGE GRAPPA
# 155  2014-01-09                   MPRAGE GRAPPA
# 156  2014-03-24                   MPRAGE GRAPPA
# 157  2014-03-10                   MPRAGE GRAPPA
# 158  2014-04-21                   MPRAGE GRAPPA
# 159  2016-07-25                MPRAGE GRAPPA_ND
# 160  2016-09-13                     MPRAGE ADNI
# 161  2015-10-06                     MPRAGE ADNI
# 162  2018-09-06                  MPRAGE GRAPPA2
# 163  2013-04-24                   MPRAGE GRAPPA
# 164  2014-05-21               Sag MPRAGE GRAPPA
# 165  2014-05-21               Sag MPRAGE GRAPPA
# 166  2013-02-13                   MPRAGE GRAPPA
# 167  2014-09-11               SAG MPRAGE GRAPPA
# 168  2013-11-12               SAG MPRAGE GRAPPA
# 169  2013-03-28                   MPRAGE GRAPPA
# 170  2013-06-25                   MPRAGE GRAPPA
# 171  2013-10-09                   MPRAGE GRAPPA
# 172  2013-08-15                   MPRAGE GRAPPA
# 173  2013-01-14                   MPRAGE GRAPPA
# 174  2013-03-11                   MPRAGE GRAPPA
# 175  2013-07-09                   MPRAGE GRAPPA
# 176  2013-03-19                   MPRAGE GRAPPA
# 177  2013-11-19                   MPRAGE GRAPPA
# 178  2013-11-05                   MPRAGE GRAPPA
# 179  2013-06-26                   MPRAGE GRAPPA
# 180  2013-09-09                   MPRAGE GRAPPA
# 181  2017-11-08                  MPRAGE GRAPPA2
# 182  2016-10-20                     MPRAGE ADNI
# 183  2019-10-23                   MPRAGE_GRAPPA
# 184  2015-02-23                   MPRAGE GRAPPA
# 185  2015-03-19                   MPRAGE GRAPPA
# 186  2017-01-05                     MPRAGE ADNI
# 187  2017-11-28                   MPRAGE_GRAPPA
# 188  2017-12-06              MPRAGE_GRAPPA_ADNI
# 189  2017-11-09                  MPRAGE GRAPPA2
# 190  2021-03-19                  3D T1-weighted
# 191  2014-05-07               Sag MPRAGE GRAPPA
# 192  2013-12-16                   MPRAGE GRAPPA
# 193  2013-10-30                   MPRAGE GRAPPA
# 194  2014-04-24                   MPRAGE GRAPPA
# 195  2015-12-01                     MPRAGE ADNI
# 196  2021-09-27                   SAG 3D MPRAGE
# 197  2021-09-02                   SAG 3D MPRAGE
# 198  2021-10-15                 SAG 3D T1 FSPGR
# 199  2021-12-17                 SAG 3D T1 FSPGR
# 200  2021-09-27                  3D T1-weighted
# 201  2021-10-21                 3D T1 _weighted
# 202  2021-11-04                 SAG 3D T1 FSPGR
# 203  2011-02-14                   MPRAGE GRAPPA
# 204  2011-03-24                   MPRAGE GRAPPA
# 205  2011-06-27                   MPRAGE GRAPPA
# 206  2011-08-10                   MPRAGE GRAPPA
# 207  2011-08-01                   MPRAGE GRAPPA
# 208  2010-11-09                   MPRAGE GRAPPA
# 209  2011-02-07                   MPRAGE GRAPPA
# 210  2011-02-01                   MPRAGE GRAPPA
# 211  2011-07-28                   MPRAGE GRAPPA
# 212  2011-06-16                   MPRAGE GRAPPA
# 213  2011-12-12                   MPRAGE GRAPPA
# 214  2011-12-16                   MPRAGE GRAPPA
# 215  2012-01-04                   MPRAGE GRAPPA
# 216  2013-04-03               SAG MPRAGE GRAPPA
# 217  2013-05-02               SAG MPRAGE GRAPPA
# 218  2011-01-18                   MPRAGE GRAPPA
# 219  2011-01-24                   MPRAGE GRAPPA
# 220  2012-01-19                   MPRAGE GRAPPA
# 221  2013-04-18                   MPRAGE GRAPPA
# 222  2011-03-18                   MPRAGE GRAPPA
# 223  2011-03-14                   MPRAGE GRAPPA
# 224  2011-03-16                   MPRAGE GRAPPA
# 225  2011-03-24                   MPRAGE GRAPPA
# 226  2011-03-31                   MPRAGE GRAPPA
# 227  2011-06-02                   MPRAGE T1 SAG
# 228  2011-09-21                   MPRAGE T1 SAG
# 229  2011-09-16                   MPRAGE T1 SAG
# 230  2013-02-21                   MPRAGE GRAPPA
# 231  2013-05-28                   MPRAGE GRAPPA
# 232  2010-10-27                   MPRAGE GRAPPA
# 233  2011-02-23                   MPRAGE GRAPPA
# 234  2011-05-25                   MPRAGE GRAPPA
# 235  2011-06-15                   MPRAGE GRAPPA
# 236  2011-06-15                   MPRAGE GRAPPA
# 237  2011-08-12                   MPRAGE GRAPPA
# 238  2011-09-13                   MPRAGE GRAPPA
# 239  2011-10-19                   MPRAGE GRAPPA
# 240  2011-11-02                   MPRAGE GRAPPA
# 241  2011-11-30                   MPRAGE GRAPPA
# 242  2011-12-14                   MPRAGE GRAPPA
# 243  2011-12-21                   MPRAGE GRAPPA
# 244  2012-01-11                   MPRAGE GRAPPA
# 245  2012-06-13                   MPRAGE GRAPPA
# 246  2011-08-08                   MPRAGE GRAPPA
# 247  2011-07-26                   MPRAGE GRAPPA
# 248  2011-10-04                   MPRAGE GRAPPA
# 249  2011-10-17                   MPRAGE GRAPPA
# 250  2011-10-24                   MPRAGE GRAPPA
# 251  2011-11-28                   MPRAGE GRAPPA
# 252  2011-12-19                   MPRAGE GRAPPA
# 253  2011-04-20                   MPRAGE GRAPPA
# 254  2011-04-13                   MPRAGE GRAPPA
# 255  2011-05-02                   MPRAGE GRAPPA
# 256  2013-06-18                MPRAGE GRAPPA_ND
# 257  2011-05-24                   MPRAGE GRAPPA
# 258  2011-06-14                   MPRAGE GRAPPA
# 259  2011-09-22                   MPRAGE GRAPPA
# 260  2012-09-21                   MPRAGE GRAPPA
# 261  2011-09-30                   MPRAGE GRAPPA
# 262  2011-09-26                   MPRAGE GRAPPA
# 263  2012-02-13                   MPRAGE GRAPPA
# 264  2013-02-05                   MPRAGE GRAPPA
# 265  2014-08-21                   MPRAGE GRAPPA
# 266  2015-08-13                     MPRAGE ADNI
# 267  2014-09-18                   MPRAGE GRAPPA
# 268  2015-02-13                   MPRAGE GRAPPA
# 269  2015-03-20                     MPRAGE ADNI
# 270  2012-04-18                   MPRAGE GRAPPA
# 271  2014-05-13                   MPRAGE GRAPPA
# 272  2013-04-08                   MPRAGE GRAPPA
# 273  2016-06-14                     MPRAGE ADNI
# 274  2014-06-19               Sag MPRAGE GRAPPA
# 275  2014-08-06                   MPRAGE GRAPPA
# 276  2014-11-19                   MPRAGE GRAPPA
# 277  2014-08-12                   MPRAGE GRAPPA
# 278  2014-07-02               SAG MPRAGE GRAPPA
# 279  2015-08-11              MPRAGE_GRAPPA_ADNI
# 280  2015-12-08              MPRAGE_GRAPPA_ADNI
# 281  2016-03-16                   MPRAGE_GRAPPA
# 282  2015-12-16                   MPRAGE_GRAPPA
# 283  2015-12-14                   MPRAGE GRAPPA
# 284  2016-03-11                   MPRAGE GRAPPA
# 285  2019-05-15              MPRAGE_GRAPPA_ADNI
# 286  2018-12-13        Accelerated Sag IR-FSPGR
# 287  2016-12-21                  MPRAGE GRAPPA2
# 288  2019-04-10              MPRAGE_GRAPPA_ADNI
# 289  2017-12-19                     MPRAGE ADNI
# 290  2017-04-24                     MPRAGE ADNI
# 291  2018-01-10                              T1
# 292  2018-09-25                              T1
# 293  2018-02-19                  MPRAGE GRAPPA2
# 294  2019-03-26                  3D Sagittal T1
# 295  2021-05-25                       SAG 3D T1
# 296  2019-01-31        Accelerated Sag IR-FSPGR
#
#                                       Imaging Protocol  Image ID EVENT_ID  \
# 0    Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1498729       BL
# 1    Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1493064       BL
# 2    Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1498753       BL
# 3    Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1562800       BL
# 4    Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1580925       BL
# 5    Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1581542       BL
# 6    Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1561861       BL
# 7    Acquisition Plane=SAGITTAL;Field Strength=3.0;...    417023      V04
# 8    Acquisition Plane=SAGITTAL;Field Strength=3.0;...    362580      V04
# 9    Acquisition Plane=SAGITTAL;Field Strength=3.0;...    374889      V04
# 10   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    374908      V04
# 11   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    382342      V04
# 12   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    415727      V04
# 13   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    378218      V06
# 14   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    449567      V06
# 15   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    372318      V06
# 16   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    397591      V06
# 17   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    440193      V06
# 18   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    378359      V06
# 19   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    353818      V06
# 20   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    414635      V06
# 21   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    449627      V06
# 22   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    554248      V06
# 23   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1494222      V06
# 24   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    393616      V04
# 25   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    436387      V04
# 26   Acquisition Plane=SAGITTAL;Field Strength=3.0;...    382346      V04
# 27   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1526357       BL
# 28   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1526373       BL
# 29   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1525725       BL
# 30   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1525538       BL
# 31   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1473678       BL
# 32   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1491213       BL
# 33   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1493035       BL
# 34   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1622593       BL
# 35   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1497614       BL
# 36   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1496183       BL
# 37   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1495841       BL
# 38   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1496212       BL
# 39   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1496225       BL
# 40   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1498714       BL
# 41   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1496289       BL
# 42   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1473261       BL
# 43   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1493057       BL
# 44   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1491235       BL
# 45   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1493072       BL
# 46   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1618837       BL
# 47   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1496300       BL
# 48   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1496443       BL
# 49   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1491246       BL
# 50   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1524081       BL
# 51   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1493080       BL
# 52   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1518940       BL
# 53   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1525871       BL
# 54   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1498794       BL
# 55   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1495900       BL
# 56   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1498810       BL
# 57   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1496495       BL
# 58   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1518956       BL
# 59   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1495920       BL
# 60   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1518962       BL
# 61   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1497660       BL
# 62   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1493096       BL
# 63   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1493107       BL
# 64   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1498856       BL
# 65   Acquisition Plane=SAGITTAL;Field Strength=3.0;...   
Acquisition Plane=SAGITTAL;Field Strength=3.0;...    419357      V04
# 193  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    412195      V04
# 194  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    430209      V04
# 195  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    615309      V04
# 196  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1518925       BL
# 197  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1498779       BL
# 198  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1525076       BL
# 199  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1537558       BL
# 200  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1519162       BL
# 201  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1547903       BL
# 202  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1530000       BL
# 203  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    226398       BL
# 204  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    235251       BL
# 205  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243563       BL
# 206  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    253901       BL
# 207  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    253995       BL
# 208  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243571       BL
# 209  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243701       BL
# 210  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243732       BL
# 211  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249254       BL
# 212  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243774       BL
# 213  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    275545       BL
# 214  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    275553       BL
# 215  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    282107       BL
# 216  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    367304       BL
# 217  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    372986       BL
# 218  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    226405       BL
# 219  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    226414       BL
# 220  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    282114       BL
# 221  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    374887      V04
# 222  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249425       BL
# 223  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249434       BL
# 224  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249440       BL
# 225  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249447       BL
# 226  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249449       BL
# 227  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243242       BL
# 228  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    265352       BL
# 229  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    259639       BL
# 230  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    367344       BL
# 231  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    374736       BL
# 232  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    226425       BL
# 233  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249264       BL
# 234  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    265355       BL
# 235  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249270       BL
# 236  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    249281       BL
# 237  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    265405       BL
# 238  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    287931       BL
# 239  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    269524       BL
# 240  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    282151       BL
# 241  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    288122       BL
# 242  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    288146       BL
# 243  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    301540       BL
# 244  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    301546       BL
# 245  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    323005       BL
# 246  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    269563       BL
# 247  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    269570       BL
# 248  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    269591       BL
# 249  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    269597       BL
# 250  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    275576       BL
# 251  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    340645       BL
# 252  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    340648       BL
# 253  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    238036       BL
# 254  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    395241       BL
# 255  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243810       BL
# 256  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    425376      V06
# 257  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243820       BL
# 258  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    243829       BL
# 259  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    395284       BL
# 260  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    395294      V04
# 261  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    275717       BL
# 262  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    288213       BL
# 263  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    334563       BL
# 264  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    367385       BL
# 265  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    449690       BL
# 266  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1412723       BL
# 267  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    449722       BL
# 268  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    475703       BL
# 269  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    491657       BL
# 270  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    305951       BL
# 271  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    437309       BL
# 272  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    377941       BL
# 273  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    757824       BL
# 274  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    440302       BL
# 275  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    482349       BL
# 276  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    466957       BL
# 277  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    449712       BL
# 278  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    437350       BL
# 279  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    515257       BL
# 280  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    615317       BL
# 281  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    689646       BL
# 282  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    615326       BL
# 283  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    615372       BL
# 284  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    665347       BL
# 285  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1224317       BL
# 286  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1196657       BL
# 287  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    864964       BL
# 288  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1224332      V06
# 289  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1003274       BL
# 290  Acquisition Plane=SAGITTAL;Field Strength=3.0;...    864977       BL
# 291  Acquisition Plane=SAGITTAL;Field Strength=1.5;...   1010555       BL
# 292  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1120681       BL
# 293  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1003465       BL
# 294  Acquisition Plane=SAGITTAL;Field Strength=1.5;...   1225080       BL
# 295  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1548775      V06
# 296  Acquisition Plane=SAGITTAL;Field Strength=3.0;...   1196810       BL
#
#       PATNO  PRIMDIAG  OTHNEURO  AGE_AT_VISIT  SEX  ... PRIMDIAG_NX  \
# 0    101070         1       NaN          67.0    1  ...           1
# 1    101175         1       NaN          70.9    1  ...           1
# 2    101279         1       NaN          69.9    1  ...           1
# 3    124793         1       NaN          60.4    0  ...           1
# 4    134605         1       NaN          65.0    1  ...           1
# 5    137886         1       NaN          73.2    1  ...           1
# 6    142879         1       NaN          80.5    0  ...           1
# 7      3386         1       NaN          72.7    0  ...           1
# 8      3757         1       NaN          71.7    1  ...           1
# 9      3758         1       NaN          70.7    1  ...           1
# 10     3771         1       NaN          75.8    0  ...           1
# 11     3776         1       NaN          64.0    1  ...           1
# 12     3834         1       NaN          69.7    1  ...           1
# 13     3107         1       NaN          71.7    1  ...           1
# 14     3321         1       NaN          72.9    0  ...           1
# 15     3352         1       NaN          53.8    1  ...           1
# 16     3359         1       NaN          74.7    1  ...           1
# 17     3378         1       NaN          49.9    1  ...           1
# 18     3552         1       NaN          61.6    1  ...           1
# 19     3557         1       NaN          61.0    1  ...           1
# 20     3763         1       NaN          61.5    1  ...           1
# 21     3826         1       NaN          79.2    1  ...           1
# 22     4081         1       NaN          73.5    1  ...           1
# 23    74067         1       NaN          72.0    0  ...           1
# 24     3374         1       NaN          71.9    1  ...           1
# 25     3392         1       NaN          51.6    0  ...           1
# 26     3777         1       NaN          62.9    1  ...           1
# 27   100005         1       NaN          52.8    1  ...           1
# 28   100006         1       NaN          55.7    0  ...           1
# 29   100007         1       NaN          67.2    1  ...           1
# 30   100012         1       NaN          66.1    0  ...           1
# 31   100017         1       NaN          58.8    0  ...           1
# 32   100842         1       NaN          63.9    1  ...           1
# 33   100878         1       NaN          65.9    1  ...           1
# 34   100889         1       NaN          74.9    0  ...           1
# 35   100891         1       NaN          62.3    1  ...           1
# 36   100898         1       NaN          75.9    1  ...           1
# 37   100911         1       NaN          73.1    1  ...           1
# 38   100952         1       NaN          50.8    0  ...           1
# 39   101018         1       NaN          62.3    1  ...           1
# 40   101026         1       NaN          46.1    1  ...           1
# 41   101047         1       NaN          75.1    1  ...           1
# 42   101092         1       NaN          69.6    0  ...           1
# 43   101124         1       NaN          73.3    1  ...           1
# 44   101174         1       NaN          55.2    1  ...           1
# 45   101179         1       NaN          44.0    0  ...           1
# 46   101186         1       NaN          78.1    1  ...           1
# 47   101187         1       NaN          62.8    1  ...           1
# 48   101295         1       NaN          65.2    1  ...           1
# 49   101476         1       NaN          68.8    1  ...           1
# 50   101482         1       NaN          58.3    1  ...           1
# 51   101492         1       NaN          44.3    1  ...           1
# 52   101516         1       NaN          70.0    0  ...           1
# 53   101675         1       NaN          75.3    0  ...           1
# 54   101735         1       NaN          61.0    0  ...           1
# 55   101748         1       NaN          62.7    0  ...           1
# 56   101751         1       NaN          39.2    1  ...           1
# 57   101799         1       NaN          61.8    1  ...           1
# 58   101841         1       NaN          78.3    0  ...           1
# 59   102053         1       NaN          60.8    1  ...           1
# 60   102054         1       NaN          62.8    1  ...           1
# 61   102078         1       NaN          53.6    1  ...           1
# 62   102293         1       NaN          68.2    1  ...           1
# 63   102484         1       NaN          63.3    1  ...           1
# 64   102978         1       NaN          54.7    0  ...           1
# 65   103809         1       NaN          36.3    1  ...           1
# 66   107099         1       NaN          63.9    1  ...           1
# 67   107648         1       NaN          78.8    1  ...           1
# 68   109451         1       NaN          68.8    1  ...           1
# 69   110212         1       NaN          71.1    0  ...           1
# 70   110360         1       NaN          61.8    1  ...           1
# 71   110535         1       NaN          59.9    1  ...           1
# 72   112729         1       NaN          79.9    1  ...           1
# 73   112926         1       NaN          71.5    0  ...           1
# 74   113446         1       NaN          68.1    1  ...           1
# 75   114526         1       NaN          59.9    1  ...           1
# 76   114615         1       NaN          65.0    1  ...           1
# 77   115448         1       NaN          68.3    1  ...           1
# 78   116531         1       NaN          67.2    1  ...           1
# 79   120544         1       NaN          77.9    0  ...           1
# 80   121619         1       NaN          59.2    1  ...           1
# 81   123594         1       NaN          52.5    1  ...           1
# 82   126130         1       NaN          58.1    1  ...           1
# 83   127741         1       NaN          70.1    1  ...           1
# 84   130013         1       NaN          64.4    1  ...           1
# 85   130156         1       NaN          61.7    1  ...           1
# 86   133486         1       NaN          61.0    1  ...           1
# 87   135579         1       NaN          62.8    1  ...           1
# 88   137426         1       NaN          63.5    1  ...           1
# 89   137482         1       NaN          70.1    0  ...           1
# 90   140041         1       NaN          56.1    0  ...           1
# 91   141135         1       NaN          53.2    1  ...           1
# 92   141696         1       NaN          51.8    1  ...           1
# 93   142004         1       NaN          75.4    0  ...           1
# 94   144147         1       NaN          56.5    1  ...           1
# 95   144254         1       NaN          72.8    1  ...           1
# 96   147077         1       NaN          57.4    0  ...           1
# 97   152582         1       NaN          73.3    1  ...           1
# 98     3125         1       NaN          47.0    1  ...           1
# 99     3132         1       NaN          50.9    1  ...           1
# 100    3168         1       NaN          64.2    0  ...           1
# 101    3173         1       NaN          63.4    0  ...           1
# 102    3174         1       NaN          51.5    1  ...           1
# 103    3175         1       NaN          58.3    0  ...           1
# 104    3179         1       NaN          52.5    1  ...           1
# 105    3184         1       NaN          60.1    0  ...           1
# 106    3185         1       NaN          55.5    0  ...           1
# 107    3308         1       NaN          68.4    1  ...           1
# 108    3309         1       NaN          55.1    0  ...           1
# 109    3325         1       NaN          67.6    0  ...           1
# 110    3327         1       NaN          55.4    0  ...           1
# 111    3328         1       NaN          64.1    1  ...           1
# 112    3372         1       NaN          72.4    1  ...           1
# 113    3373         1       NaN          62.1    1  ...           1
# 114    3375         1       NaN          51.1    1  ...           1
# 115    3377         1       NaN          54.8    0  ...           1
# 116    3380         1       NaN          71.1    0  ...           1
# 117    3387         1       NaN          57.5    0  ...           1
# 118    3575         1       NaN          62.1    1  ...           1
# 119    3585         1       NaN          50.3    1  ...           1
# 120    3587         1       NaN          53.6    1  ...           1
# 121    3592         1       NaN          63.4    1  ...           1
# 122    3593         1       NaN          56.4    0  ...           1
# 123    3762         1       NaN          71.5    0  ...           1
# 124    3770         1       NaN          55.7    0  ...           1
# 125    3775         1       NaN          63.9    1  ...           1
# 126    3778         1       NaN          53.0    0  ...           1
# 127    3780         1       NaN          71.0    0  ...           1
# 128    3789         1       NaN          58.5    0  ...           1
# 129    3814         1       NaN          68.5    1  ...           1
# 130    3819         1       NaN          53.9    0  ...           1
# 131    3822         1       NaN          57.0    1  ...           1
# 132    3823         1       NaN          58.0    1  ...           1
# 133    3824         1       NaN          56.3    0  ...           1
# 296          HC     27.459921        2.288327   sub-75479_ses-BL
#
# [297 rows x 31 columns]

# %%
cohort = pd.concat([mci, wo_mci_all, hc], ignore_index=True)
cohort = cohort.drop_duplicates(subset=["PATNO"])
print("There are ", len(cohort), " unique subjects.")
# Out:
# There are  447  unique subjects.

# %%
# calculate time difference between the visits (Duration T2-T1)
cohort["Study Date"] = pd.to_datetime(cohort["Study Date"])
cohort["Study Date_NX"] = pd.to_datetime(cohort["Study Date_NX"])
cohort["durationT2_T1"] = cohort["Study Date_NX"] - cohort["Study Date"]
cohort["durationT2_T1_y"] = cohort["durationT2_T1"].dt.days / 365.25

# %% [markdown]
# ## Descriptive statistics (computational cohort)
#
# To calculate descriptive statistics we exclude images that failed preprocessing in the next steps. PPMI's Data Usage Agreement prevents us from publicaly sharing subjects' identifiers.

# %%
def set_patno_id(df):
    df["PATNO_id"] = "sub-" + df["PATNO"].astype(str) + "_ses-" + df["EVENT_ID"]

# %%
def into_cross_sectional(cohort: pd.DataFrame, verbose: bool = False) -> pd.DataFrame:
    """Convert longitudinal cohort dataframe into cross-sectional format."""
    columns_all = cohort.columns.to_list()
    columns_followup = [col for col in cohort.columns if col.endswith("_NX")]
    columns_baseline = [col.replace("_NX", "") for col in columns_followup]
    columns_followup += ["NEXT_VISIT"]
    columns_shared = list(
        set(columns_all) - (set(columns_baseline) | set(columns_followup))
    )
    if verbose:
        print(f"All columns {columns_all}")
        print(f"Follow-up columns {columns_followup}")
        print(f"Baseline columns {columns_baseline}")
        print(f"Shared columns {columns_shared}")

    cohort_stat = cohort.copy()
    cohort_stat_baseline = cohort[columns_shared + columns_baseline].copy()
    cohort_stat_followup = cohort[columns_shared + columns_followup].copy()
    cohort_stat_baseline = cohort_stat_baseline.rename(
        columns={col: col.replace("_NX", "") for col in columns_baseline}
    )
    cohort_stat_followup = cohort_stat_followup.rename(
        columns={
            col: col.replace("_NX", "")
            for col in columns_followup
            if col != "NEXT_VISIT"
        }
    )
    cohort_stat_followup["AGE_AT_VISIT"] = round(
        cohort_stat_followup["AGE_AT_VISIT"] + cohort_stat_followup["durationT2_T1_y"],
        1,
    )
    cohort_stat_followup.drop(columns=["NEXT_VISIT"], inplace=True)

    set_patno_id(cohort_stat_baseline)
    set_patno_id(cohort_stat_followup)

    cohort_stat_baseline.rename(columns={"EVENT_ID": "visit"}, inplace=True)
    cohort_stat_followup.rename(columns={"EVENT_ID": "visit"}, inplace=True)

    assert (
        cohort_stat_baseline.columns.to_list() == cohort_stat_followup.columns.to_list()
    )

    cohort_stat_baseline["timepoint"] = "T1"
    cohort_stat_followup["timepoint"] = "T2"

    cohort_stat = pd.concat(
        [cohort_stat_baseline, cohort_stat_followup], ignore_index=True
    )
    cohort_stat.sort_values(by=["PATNO_id"], inplace=True)
    return cohort_stat

# %%
cohort_stat_raw = into_cross_sectional(cohort)
unique_patno_ids = cohort_stat_raw["PATNO"].nunique()
filename = cohort_dir / "cross-sectional_cohort_raw.csv"
cohort_stat_raw.to_csv(filename, index=False)
print(f"{unique_patno_ids} unique subjects found")
print(f"Saved cross-sectional_cohort_raw.csv to {anondir(filename.resolve())}")
# Out:
# 447 unique subjects found
# Saved cross-sectional_cohort_raw.csv to <living-park>/cohort/cross-sectional_cohort_raw.csv

# %%
vip_results = pd.read_csv(root_dir / "cohort" / "vip_executions_stats_info.csv")
# Select only subjects that has been processed on VIP platform
# since rerunning the cohort builder will download new MRI metadata
cohort_stat_exp = cohort_stat_raw[
    cohort_stat_raw["PATNO_id"].isin(vip_results["subject_visit"])
]
unique_patno_ids = cohort_stat_exp["PATNO"].nunique()
filename = cohort_dir / "cross-sectional_cohort_exp.csv"
cohort_stat_exp.to_csv(filename, index=False)
print(f"{unique_patno_ids} unique subjects found")
print(f"Saved cross-sectional_cohort_exp.csv to {anondir(filename.resolve())}")
# Out:
# 317 unique subjects found
# Saved cross-sectional_cohort_exp.csv to <living-park>/cohort/cross-sectional_cohort_exp.csv

# %%
qc_results = pd.read_csv(
    root_dir
    / "cohort"
    / "vip_executions_stats_info_2visits_passed_qc_with_26_repetitions.csv"
)
cohort_stat_qced = cohort_stat_raw[
    cohort_stat_raw["PATNO_id"].isin(qc_results["subject_visit"])
]
unique_patno_ids = cohort_stat_qced["PATNO"].nunique()
filename = cohort_dir / "cross-sectional_cohort_qced.csv"
cohort_stat_qced.to_csv(filename, index=False)
print(f"{unique_patno_ids} unique PATNO id found")
print(f"Saved cross-sectional_cohort_qced.csv to {anondir(filename.resolve())}")
# Out:
# 267 unique PATNO id found
# Saved cross-sectional_cohort_qced.csv to <living-park>/cohort/cross-sectional_cohort_qced.csv

# %%
from collections.abc import Iterable

import rich
from rich.console import Console
from rich.table import Table


def cohort_summary(*, hc, nc, mci, title):
    def gen_row(D, *, agg, col, f="4.1f", sep=" ± "):
        if not isinstance(agg, str) and isinstance(agg, Iterable):
            return [f"{sep}".join([f"{d.loc[a][col]:{f}}" for a in agg]) for d in D]
        else:
            return [f"{d.loc[agg][col]:{f}}" for d in D]

    def gender_ratio(df):
        male_count = df[df["SEX"] == 1]["PATNO"].nunique()
        return f"{male_count:.0f}, {male_count / df['PATNO'].nunique() * 100:.1f}%"

    D = [hc.describe(), nc.describe(), mci.describe()]

    table = Table(title=title, box=rich.box.SIMPLE_HEAVY, show_footer=True)

    table.add_column("Subject groups", footer="Values expressed as mean ± SD.")
    table.add_column("HC")
    table.add_column("PD-non-MCI")
    table.add_column("PD-MCI")

    table.add_row("n", *gen_row(D, agg="count", col="PATNO", f=".0f"))
    table.add_row("Age (y)", *gen_row(D, agg=["mean", "std"], col="AGE_AT_VISIT"))
    table.add_row(
        "Age range", *gen_row(D, agg=["min", "max"], col="AGE_AT_VISIT", sep=" - ")
    )
    table.add_row(
        "Gender (male, %)", gender_ratio(hc), gender_ratio(nc), gender_ratio(mci)
    )
    table.add_row("Education (y)", *gen_row(D, agg=["mean", "std"], col="EDUCYRS"))

    console = Console()
    console.print(table)

# %% [markdown]
# ### Demographic of raw data

# %%
def show_demographics(cohort, timepoint="T1"):
    cohort = cohort[cohort["timepoint"] == timepoint]
    hc = cohort[cohort["dx_group"] == "HC"]
    nc = cohort[cohort["dx_group"] == "PD-non-MCI"]
    mci = cohort[cohort["dx_group"] == "PD-MCI"]

    cohort_summary(
        hc=hc,
        nc=nc,
        mci=mci,
        title="Demographic and clinical characteristics",
    )

# %%
show_demographics(cohort_stat_raw)
# Out:
#                   Demographic and clinical characteristics
#
#   Subject groups                   HC            PD-non-MCI    PD-MCI
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   n                                138           273           36
#   Age (y)                          61.6 ±  9.3   61.9 ±  9.5   67.6 ±  7.5
#   Age range                        30.6 - 84.3   36.3 - 83.9   49.9 - 80.5
#   Gender (male, %)                 67, 48.6%     180, 65.9%    26, 72.2%
#   Education (y)                    16.7 ±  3.2   16.2 ±  3.2   15.4 ±  3.5
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Values expressed as mean ± SD.

# %% [markdown]
# ### Demographic of data preprocess with freesurfer-fuzzy

# %%
show_demographics(cohort_stat_exp)
# Out:
#                   Demographic and clinical characteristics
#
#   Subject groups                   HC            PD-non-MCI    PD-MCI
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   n                                107           181           29
#   Age (y)                          60.5 ± 10.2   61.7 ±  9.6   67.7 ±  7.7
#   Age range                        30.6 - 84.3   36.3 - 83.3   49.9 - 80.5
#   Gender (male, %)                 59, 55.1%     119, 65.7%    22, 75.9%
#   Education (y)                    16.6 ±  3.3   15.9 ±  2.9   15.1 ±  3.5
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Values expressed as mean ± SD.

# %% [markdown]
# ### Demographic of data QCed with 26 repetitions

# %%
show_demographics(cohort_stat_qced)
# Out:
#                   Demographic and clinical characteristics
#
#   Subject groups                   HC            PD-non-MCI    PD-MCI
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   n                                89            157           21
#   Age (y)                          60.7 ±  9.7   61.1 ±  9.5   67.6 ±  7.7
#   Age range                        30.6 - 79.8   36.3 - 79.9   51.6 - 80.5
#   Gender (male, %)                 47, 52.8%     102, 65.0%    14, 66.7%
#   Education (y)                    16.7 ±  3.4   15.8 ±  3.0   14.8 ±  3.5
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Values expressed as mean ± SD.

# %%
from scipy.stats import ttest_ind, chi2_contingency
import numpy as np
import pandas as pd
from rich.console import Console
from rich.table import Table
from rich import box

console = Console()


def test_group_diff_age(group1, group2):
    t, p = ttest_ind(group1["AGE_AT_VISIT"], group2["AGE_AT_VISIT"])
    return t, p


def test_group_diff_edu(group1, group2):
    t, p = ttest_ind(group1["EDUCYRS"], group2["EDUCYRS"], nan_policy="omit")
    return t, p


def test_group_diff_duration(group1, group2):
    t, p = ttest_ind(group1["durationT2_T1_y"], group2["durationT2_T1_y"])
    return t, p


def test_group_diff_sex(group1, group2):
    a1 = group1["SEX"].value_counts()[0]
    a2 = group1["SEX"].value_counts()[1]
    b1 = group2["SEX"].value_counts()[0]
    b2 = group2["SEX"].value_counts()[1]

    obs = np.array([[a1, a2], [b1, b2]])
    chi2_test = chi2_contingency(obs)
    return chi2_test


def show_group_diff_rich(
    group1,
    group2,
    alpha: float = 0.05,
):
    """
    Computes:
        - Age t-test
        - Education t-test
        - Duration t-test
        - Sex chi² test
    And prints results in a Rich table with:
        - bold red p-values if significant (< alpha)
        - bold statistics for significant results
    """
    # ---- Compute tests using your existing functions ----
    t_age, p_age = test_group_diff_age(group1, group2)
    t_edu, p_edu = test_group_diff_edu(group1, group2)
    t_dur, p_dur = test_group_diff_duration(group1, group2)
    chi2_stat, chi2_p, _, chi2_table = test_group_diff_sex(group1, group2)

    # ---- Rich Table ----
    table = Table(
        title="Group Difference Tests",
        box=box.SIMPLE_HEAVY,
        show_lines=False,
        header_style="bold cyan",
    )

    table.add_column("Variable", justify="left")
    table.add_column("Statistic", justify="right")
    table.add_column("p-value", justify="right")
    table.add_column("Significant", justify="center")

    # Helper to format and color p-values
    def fmt_p(p):
        if p < alpha:
            return f"[bold red]{p:.4f}[/]"
        else:
            return f"{p:.4f}"

    def fmt_stat(stat, p):
        if p < alpha:
            return f"[bold]{stat:.4f}[/]"
        else:
            return f"{stat:.4f}"

    # Add rows
    table.add_row(
        "Age", fmt_stat(t_age, p_age), fmt_p(p_age), "✅" if p_age < alpha else "–"
    )

    table.add_row(
        "Education",
        fmt_stat(t_edu, p_edu),
        fmt_p(p_edu),
        "✅" if p_edu < alpha else "–",
    )

    table.add_row(
        "Duration (T2 - T1)",
        fmt_stat(t_dur, p_dur),
        fmt_p(p_dur),
        "✅" if p_dur < alpha else "–",
    )

    table.add_row(
        "Sex (Chi²)",
        fmt_stat(chi2_stat, chi2_p),
        fmt_p(chi2_p),
        "✅" if chi2_p < alpha else "–",
    )

    console.print(table)

    # Optional: print contingency table below
    console.print("\n[bold]Sex contingency table:[/]")
    console.print(pd.DataFrame(chi2_table))


def show_group_differences(cohort, timepoint="T1"):
    cohort = cohort[cohort["timepoint"] == timepoint]
    hc = cohort[cohort["dx_group"] == "HC"]
    nc = cohort[cohort["dx_group"] == "PD-non-MCI"]
    mci = cohort[cohort["dx_group"] == "PD-MCI"]
    pd_all = pd.concat([nc, mci], ignore_index=True)
    show_group_diff_rich(pd_all, hc)

# %%
show_group_differences(cohort_stat_raw)
# Out:
#                   Group Difference Tests
#
#   Variable             Statistic   p-value   Significant
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Age                     0.9965    0.3195        –
#   Education              -1.6327    0.1032        –
#   Duration (T2 - T1)     -0.3695    0.7120        –
#   Sex (Chi²)             12.4181    0.0004       ✅
# Sex contingency table:
#             0           1
# 0  120.281879  188.718121
# 1   53.718121   84.281879

# %%
show_group_differences(cohort_stat_exp)
# Out:
#                   Group Difference Tests
#
#   Variable             Statistic   p-value   Significant
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Age                     1.7376    0.0833        –
#   Education              -2.0446    0.0417       ✅
#   Duration (T2 - T1)     -0.6977    0.4859        –
#   Sex (Chi²)              3.8850    0.0487       ✅
# Sex contingency table:
#            0           1
# 0  77.507886  132.492114
# 1  39.492114   67.507886

# %%
show_group_differences(cohort_stat_qced)
# Out:
#                   Group Difference Tests
#
#   Variable             Statistic   p-value   Significant
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Age                     1.0051    0.3158        –
#   Education              -2.3809    0.0180       ✅
#   Duration (T2 - T1)     -1.1605    0.2469        –
#   Sex (Chi²)              3.3095    0.0689        –
# Sex contingency table:
#            0           1
# 0  69.333333  108.666667
# 1  34.666667   54.333333

# %% [markdown]
# # Define PD cohorts with UPDRS

# %%
# Merge into a single df for PD

df_clinical = (
    mri.merge(diag, on=["PATNO", "EVENT_ID"])
    .merge(age, on=["PATNO", "EVENT_ID"], how="left")
    .merge(dem, on=["PATNO"])
    .merge(edu, on=["PATNO"], how="left")
    .merge(dx_status, on=["PATNO"])
    .merge(pd_hist, on=["PATNO", "EVENT_ID"], how="left")
    .merge(cog_cat, on=["PATNO", "EVENT_ID"])
    .merge(updrs, on=["PATNO", "EVENT_ID"])  #
    .drop_duplicates()
    .groupby("PATNO")
    .filter(lambda g: g["EVENT_ID"].nunique() > 1)
)

# %%
# find PD-non-MCI with UPDRS score


def get_nonmci_with_UPDRS_patients(df):
    return df.loc[
        (df["COGSTATE"] == 1)
        & (df["PRIMDIAG"] == 1)
        & (df["COHORT"] == 1)
        & (df["OTHNEURO"].isnull())
        & (df["PDSTATE"] == "OFF")
        & (df["COGSTATE_NX"] == 1)
        & (df["PRIMDIAG_NX"] == 1)
        & (df["COHORT_NX"] == 1)
        & (df["OTHNEURO_NX"].isnull())
        & (df["PDSTATE_NX"] == "OFF")
    ]


def pairs_nonmci_with_UPDRS(arg):
    visit_pairs = find_visit_pairs(arg)
    visit_df = df_clinical.copy()
    visit_df["NEXT_VISIT"] = visit_df["EVENT_ID"].map(visit_pairs)

    visit_df = visit_df.merge(
        visit_df.drop(
            ["AGE_AT_VISIT", "SEX", "NEXT_VISIT", "EDUCYRS"],
            axis=1,
        ),
        left_on=[
            "PATNO",
            "NEXT_VISIT",
        ],
        right_on=[
            "PATNO",
            "EVENT_ID",
        ],
        suffixes=(None, "_NX"),
    ).drop_duplicates()

    return get_nonmci_with_UPDRS_patients(visit_df)

# %%
wo_mci_12 = pairs_nonmci_with_UPDRS(12)
wo_mci_24 = pairs_nonmci_with_UPDRS(24)
wo_mci_36 = pairs_nonmci_with_UPDRS(36)
wo_mci_all = pd.concat([wo_mci_12, wo_mci_24, wo_mci_36], ignore_index=True)
wo_mci_all = wo_mci_all.drop_duplicates(subset=["PATNO"])
wo_mci_all["dx_group"] = "PD-non-MCI"

wo_mci_all = wo_mci_all[~wo_mci_all["NP3TOT"].isna()]
wo_mci_all = wo_mci_all[~wo_mci_all["NP3TOT_NX"].isna()]

print("There are ", len(wo_mci_all), " PD-non-MCI patients.")
# Out:
# There are  139  PD-non-MCI patients.

# %%
# calculate the time difference between the visits
pd_clinical_raw = wo_mci_all

pd_clinical_raw["Study Date"] = pd.to_datetime(pd_clinical_raw["Study Date"])
pd_clinical_raw["Study Date_NX"] = pd.to_datetime(pd_clinical_raw["Study Date_NX"])
pd_clinical_raw["durationT2_T1"] = (
    pd_clinical_raw["Study Date_NX"] - pd_clinical_raw["Study Date"]
)
pd_clinical_raw["durationT2_T1_y"] = pd_clinical_raw["durationT2_T1"].dt.days / 365.25

# visit ID
set_patno_id(pd_clinical_raw)

# calculate the change of UPDRS score
pd_clinical_raw["NP3TOT_change"] = (
    pd_clinical_raw["NP3TOT"] - pd_clinical_raw["NP3TOT_NX"]
)

unique_patno_ids = pd_clinical_raw["PATNO_id"].nunique()
print(f"{unique_patno_ids} unique PD PATNO id found")
filename = cohort_dir / "pd_longitudinal_raw.csv"
pd_clinical_raw.to_csv(filename, index=False)
print(f"Saved pd_longitudinal_raw.csv to {anondir(filename.resolve())}")
# Out:
# 139 unique PD PATNO id found
# Saved pd_longitudinal_raw.csv to <living-park>/cohort/pd_longitudinal_raw.csv

# %%
pd_clinical_exp = pd_clinical_raw[
    pd_clinical_raw["PATNO_id"].isin(vip_results["subject_visit"])
]
unique_patno_ids = pd_clinical_exp["PATNO_id"].nunique()
print(f"{unique_patno_ids} unique PD PATNO id found")
filename = cohort_dir / "pd_longitudinal_exp.csv"
pd_clinical_exp.to_csv(filename, index=False)
print(f"Saved pd_longitudinal_exp.csv to {anondir(filename.resolve())}")
# Out:
# 125 unique PD PATNO id found
# Saved pd_longitudinal_exp.csv to <living-park>/cohort/pd_longitudinal_exp.csv

# %%
pd_clinical_qced = pd_clinical_raw[
    pd_clinical_raw["PATNO_id"].isin(qc_results["subject_visit"])
]
unique_patno_ids = pd_clinical_qced["PATNO_id"].nunique()
print(f"{unique_patno_ids} unique PD PATNO id found")
filename = cohort_dir / "pd_longitudinal_qced.csv"
pd_clinical_qced.to_csv(filename, index=False)
print(f"Saved pd_longitudinal_qced.csv to {anondir(filename.resolve())}")
# Out:
# 112 unique PD PATNO id found
# Saved pd_longitudinal_qced.csv to <living-park>/cohort/pd_longitudinal_qced.csv

# %% [markdown]
# ## Descriptive statistics (clinical cohort)

# %%
from collections.abc import Iterable

import rich
from rich.console import Console
from rich.table import Table


def clinical_cohort_summary(*, hc, nc, title):
    def gen_row(D, *, agg, col, f="4.1f", sep=" ± "):
        if not isinstance(agg, str) and isinstance(agg, Iterable):
            return [f"{sep}".join([f"{d.loc[a][col]:{f}}" for a in agg]) for d in D]
        else:
            return [f"{d.loc[agg][col]:{f}}" for d in D]

    def gender_ratio(df):
        male_count = df[df["SEX"] == 1]["PATNO"].nunique()
        return f"{male_count:.0f}, {male_count / df['PATNO'].nunique() * 100:.1f}%"

    D = [hc.describe(), nc.describe()]

    table = Table(title=title, box=rich.box.SIMPLE_HEAVY, show_footer=True)

    table.add_column("Subject groups", footer="Values expressed as mean ± SD.")
    table.add_column("HC")
    table.add_column("PD-non-MCI")
    # table.add_column("[italic]p")  # TODO

    table.add_row("n", *gen_row(D, agg="count", col="PATNO", f=".0f"))
    table.add_row("Age (y)", *gen_row(D, agg=["mean", "std"], col="AGE_AT_VISIT"))
    table.add_row(
        "Age range", *gen_row(D, agg=["min", "max"], col="AGE_AT_VISIT", sep=" - ")
    )
    table.add_row("Gender (male, %)", gender_ratio(hc), gender_ratio(nc))
    table.add_row("Education (y)", *gen_row(D, agg=["mean", "std"], col="EDUCYRS"))
    table.add_row(
        "UPDRS III OFF baseline", "", *gen_row(D[1:], agg=["mean", "std"], col="NP3TOT")
    )
    table.add_row(
        "UPDRS III OFF follow-up",
        "",
        *gen_row(D[1:], agg=["mean", "std"], col="NP3TOT_NX"),
    )
    table.add_row(
        "Duration T2 - T1 (y)", *gen_row(D, agg=["mean", "std"], col="durationT2_T1_y")
    )

    console = Console()
    console.print(table)

# %% [markdown]
# ### Demographic clinical raw population

# %%
filename = cohort_dir / "pd_longitudinal_raw.csv"
pd_clinical_raw = pd.read_csv(filename)
filename = cohort_dir / "hc_longitudinal_raw.csv"
hc_raw.to_csv(filename, index=False)

pd_nonmci_clinical_raw = pd_clinical_raw[pd_clinical_raw["dx_group"] == "PD-non-MCI"]
pd_nonmci_clinical_raw.to_csv("pd_nonmci_longitudinal_raw.csv", index=False)

clinical_cohort_summary(
    hc=hc_raw,
    nc=pd_nonmci_clinical_raw,
    title="Demographic and clinical characteristics",
)
# Out:
#            Demographic and clinical characteristics
#
#   Subject groups                   HC            PD-non-MCI
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   n                                138           139
#   Age (y)                          61.6 ±  9.3   61.6 ±  9.3
#   Age range                        30.6 - 84.3   39.2 - 83.9
#   Gender (male, %)                 67, 48.6%     94, 67.6%
#   Education (y)                    16.7 ±  3.2   16.0 ±  3.0
#   UPDRS III OFF baseline                         23.8 ±  9.9
#   UPDRS III OFF follow-up                        26.9 ± 11.7
#   Duration T2 - T1 (y)              1.3 ±  0.5    1.4 ±  0.7
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Values expressed as mean ± SD.

# %%
filename = cohort_dir / "pd_longitudinal_exp.csv"
pd_clinical_exp = pd.read_csv(filename)
filename = cohort_dir / "hc_longitudinal_exp.csv"
hc_exp.to_csv(filename, index=False)

pd_nonmci_clinical_exp = pd_clinical_exp[pd_clinical_exp["dx_group"] == "PD-non-MCI"]
pd_nonmci_clinical_exp.to_csv("pd_nonmci_longitudinal_exp.csv", index=False)

clinical_cohort_summary(
    hc=hc_exp,
    nc=pd_nonmci_clinical_exp,
    title="Demographic and clinical characteristics",
)
# Out:
#            Demographic and clinical characteristics
#
#   Subject groups                   HC            PD-non-MCI
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   n                                107           125
#   Age (y)                          60.5 ± 10.2   61.1 ±  9.3
#   Age range                        30.6 - 84.3   39.2 - 83.3
#   Gender (male, %)                 59, 55.1%     84, 67.2%
#   Education (y)                    16.6 ±  3.3   16.1 ±  3.0
#   UPDRS III OFF baseline                         23.8 ± 10.2
#   UPDRS III OFF follow-up                        26.3 ± 11.6
#   Duration T2 - T1 (y)              1.4 ±  0.5    1.4 ±  0.7
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Values expressed as mean ± SD.

# %%
filename = cohort_dir / "pd_longitudinal_qced.csv"
pd_clinical_qced = pd.read_csv(filename)
filename = cohort_dir / "hc_longitudinal_qced.csv"
hc_qced.to_csv(filename, index=False)

pd_nonmci_clinical_qced = pd_clinical_qced[pd_clinical_qced["dx_group"] == "PD-non-MCI"]
pd_nonmci_clinical_qced.to_csv("pd_nonmci_longitudinal_qced.csv", index=False)

clinical_cohort_summary(
    hc=hc_qced,
    nc=pd_nonmci_clinical_qced,
    title="Demographic and clinical characteristics",
)
# Out:
#            Demographic and clinical characteristics
#
#   Subject groups                   HC            PD-non-MCI
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   n                                89            112
#   Age (y)                          60.7 ±  9.7   60.6 ±  8.9
#   Age range                        30.6 - 79.8   39.2 - 78.3
#   Gender (male, %)                 47, 52.8%     74, 66.1%
#   Education (y)                    16.7 ±  3.4   16.0 ±  3.1
#   UPDRS III OFF baseline                         23.3 ± 10.0
#   UPDRS III OFF follow-up                        25.6 ± 11.2
#   Duration T2 - T1 (y)              1.4 ±  0.5    1.4 ±  0.6
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Values expressed as mean ± SD.

# %%
show_group_diff_rich(pd_nonmci_clinical_raw, hc_raw, alpha=0.05)
# Out:
#                   Group Difference Tests
#
#   Variable             Statistic   p-value   Significant
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Age                     0.0099    0.9921        –
#   Education              -1.7756    0.0769        –
#   Duration (T2 - T1)      1.5885    0.1133        –
#   Sex (Chi²)              9.5832    0.0020       ✅
# Sex contingency table:
#            0          1
# 0  58.209386  80.790614
# 1  57.790614  80.209386

# %%
show_group_diff_rich(pd_nonmci_clinical_exp, hc_exp, alpha=0.05)
# Out:
#                   Group Difference Tests
#
#   Variable             Statistic   p-value   Significant
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Age                     0.4321    0.6661        –
#   Education              -1.0697    0.2859        –
#   Duration (T2 - T1)      0.7299    0.4662        –
#   Sex (Chi²)              3.0543    0.0805        –
# Sex contingency table:
#            0          1
# 0  47.952586  77.047414
# 1  41.047414  65.952586

# %%
show_group_diff_rich(pd_nonmci_clinical_qced, hc_qced, alpha=0.05)
# Out:
#                   Group Difference Tests
#
#   Variable             Statistic   p-value   Significant
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Age                    -0.0350    0.9721        –
#   Education              -1.4785    0.1409        –
#   Duration (T2 - T1)      0.1286    0.8978        –
#   Sex (Chi²)              3.1081    0.0779        –
# Sex contingency table:
#            0          1
# 0  44.577114  67.422886
# 1  35.422886  53.577114

# %%
def build_clinical_cohort(df):
    df["first_visit"] = "sub-" + df["PATNO"].astype(str) + "_ses-" + df["EVENT_ID"]
    df["second_visit"] = "sub-" + df["PATNO"].astype(str) + "_ses-" + df["EVENT_ID_NX"]
    set_patno_id(df)
    return df

# %%
clinical_cohort_raw = pd.concat([pd_nonmci_clinical_raw, hc_raw], ignore_index=True)
clinical_cohort_raw = build_clinical_cohort(clinical_cohort_raw)
filename = cohort_dir / "longitudinal_cohort_raw.csv"
clinical_cohort_raw.to_csv(filename, index=False)
print(f"Saved longitudinal_cohort_raw.csv to {anondir(filename.resolve())}")
# Out:
# Saved longitudinal_cohort_raw.csv to <living-park>/cohort/longitudinal_cohort_raw.csv

# %%
clinical_cohort_exp = pd.concat([pd_nonmci_clinical_exp, hc_exp], ignore_index=True)
clinical_cohort_exp = build_clinical_cohort(clinical_cohort_exp)
filename = cohort_dir / "longitudinal_cohort_exp.csv"
clinical_cohort_exp.to_csv(filename, index=False)
print(f"Saved longitudinal_cohort_exp.csv to {anondir(filename.resolve())}")
# Out:
# Saved longitudinal_cohort_exp.csv to <living-park>/cohort/longitudinal_cohort_exp.csv

# %%
clinical_cohort_qced = pd.concat([pd_nonmci_clinical_qced, hc_qced], ignore_index=True)
clinical_cohort_qced = build_clinical_cohort(clinical_cohort_qced)
filename = cohort_dir / "longitudinal_cohort_qced.csv"
clinical_cohort_qced.to_csv(filename, index=False)
print(f"Saved longitudinal_cohort_qced.csv to {anondir(filename.resolve())}")
# Out:
# Saved longitudinal_cohort_qced.csv to <living-park>/cohort/longitudinal_cohort_qced.csv
